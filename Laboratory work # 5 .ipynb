# %% [markdown]
# Introduction to working with files.
#
# Step 1. Reading data from text files

# %%
# def removeDublicate(l ):
#     for i in range(len(l)):
#         if l[i] != l[i-1]:
#             u.append(l[i])
#     return u 
    
    
# u = []
# l =[]
with open("/Users/shopangali05/Downloads/My file/IT3-2208/4 семестр/python/laborotory work/laboratory work # 5 /user_ids.txt","r") as f:
    for line in f:
#         l.append(line.strip().strip(','))
        print(line.strip())
# print(l[2])
# print()
# print(l)


# result = removeDublicate(l)
# print(result)
# print(len(result))
# Out:
# 1010
# 1036
# 1041
# 1041
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1047
# 1047
# 1052
# 1052
# 1057
# 1057
# 1062
# 1067
# 1078
# 1085
# 1096
# 1098
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1105
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1111
# 1112
# 1112
# 1113
# 1113
# 1114
# 1114
# 1116
# 1118
# 1118
# 1123
# 1123
# 1128
# 1134
# 1134
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1136
# 1136
# 1140
# 1140
# 1141
# 1145
# 1145
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1150
# 1154
# 1154
# 1159
# 1159
# 1164
# 1167
# 1175
# 1181
# 1182
# 1182
# 1193
# 1193
# 1198
# 1198
# 1201
# 1203
# 1203
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1208
# 1208
# 1209
# 1213
# 1213
# 1218
# 1218
# 1219
# 1223
# 1223
# 1224
# 1226
# 1226
# 1228
# 1228
# 1230
# 1233
# 1233
# 1236
# 1238
# 1238
# 1242
# ...

# %% [markdown]
# #

# %% [markdown]
# Step 2. Reading file content into list

# %%
users_ids = [] 
l = []
with open("/Users/shopangali05/Downloads/My file/IT3-2208/4 семестр/python/laborotory work/laboratory work # 5 /user_ids.txt","r") as f:
    for line in f:
        users_ids.append(line.strip().strip(','))
# print(users_ids)
l.append(users_ids[0])
l.append(users_ids[1])
l.append(users_ids[2])
l.append(users_ids[3])
l.append(users_ids[4])
print(l)
print()
print(users_ids[-1])
# Out:
# ['1010', '1036', '1041', '1041', '1042']
#
# 1424

# %% [markdown]
# Step 3. Count the unique numbers of elements

# %%
users_ids = [] 
with open("/Users/shopangali05/Downloads/My file/IT3-2208/4 семестр/python/laborotory work/laboratory work # 5 /user_ids.txt","r") as f:
    for line in f:
        users_ids.append(line.strip().strip(','))
unique_ids = set(users_ids)
print( 'Unique IDs in the file {}'.format(len(unique_ids)))
# count = 0
# for i in unique_ids:
#     count += 1 
# print(count)
# Out:
# Unique IDs in the file 124

# %% [markdown]
# Files with headers and multiple columns
#
# Step 1. Reading header files

# %%
with open('/Users/shopangali05/Downloads/My file/IT3-2208/4 семестр/python/laborotory work/laboratory work # 5 /user_ids_header.txt', 'r') as f:
    for line in f:
        print(line.strip())
# Out:
# user_id
# 1010
# 1036
# 1041
# 1041
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1047
# 1047
# 1052
# 1052
# 1057
# 1057
# 1062
# 1067
# 1078
# 1085
# 1096
# 1098
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1105
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1111
# 1112
# 1112
# 1113
# 1113
# 1114
# 1114
# 1116
# 1118
# 1118
# 1123
# 1123
# 1128
# 1134
# 1134
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1136
# 1136
# 1140
# 1140
# 1141
# 1145
# 1145
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1150
# 1154
# 1154
# 1159
# 1159
# 1164
# 1167
# 1175
# 1181
# 1182
# 1182
# 1193
# 1193
# 1198
# 1198
# 1201
# 1203
# 1203
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1208
# 1208
# 1209
# 1213
# 1213
# 1218
# 1218
# 1219
# 1223
# 1223
# 1224
# 1226
# 1226
# 1228
# 1228
# 1230
# 1233
# 1233
# 1236
# 1238
# 1238
# ...

# %% [markdown]
# Step 2. How avoid the first line

# %%
Started = True

with open('/Users/shopangali05/Downloads/My file/IT3-2208/4 семестр/python/laborotory work/laboratory work # 5 /user_ids_header.txt', 'r') as f:
    for line in f:
        if Started:
            Started = False
        else:
            print(line.strip())
# Out:
# 1010
# 1036
# 1041
# 1041
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1042
# 1047
# 1047
# 1052
# 1052
# 1057
# 1057
# 1062
# 1067
# 1078
# 1085
# 1096
# 1098
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1100
# 1105
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1108
# 1111
# 1112
# 1112
# 1113
# 1113
# 1114
# 1114
# 1116
# 1118
# 1118
# 1123
# 1123
# 1128
# 1134
# 1134
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1135
# 1136
# 1136
# 1140
# 1140
# 1141
# 1145
# 1145
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1149
# 1150
# 1154
# 1154
# 1159
# 1159
# 1164
# 1167
# 1175
# 1181
# 1182
# 1182
# 1193
# 1193
# 1198
# 1198
# 1201
# 1203
# 1203
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1207
# 1208
# 1208
# 1209
# 1213
# 1213
# 1218
# 1218
# 1219
# 1223
# 1223
# 1224
# 1226
# 1226
# 1228
# 1228
# 1230
# 1233
# 1233
# 1236
# 1238
# 1238
# 1242
# ...

# %% [markdown]
# Step 3. Reading data from files with multiple columns

# %%
with open('/Users/shopangali05/Downloads/My file/IT3-2208/4 семестр/python/laborotory work/laboratory work # 5 /data_3_columns.txt', 'r') as f:
    for line in f:
        line = line.strip().split('\t')
        print( line)
# Out:
# ['seo', 'google', '20,20']
# ['sem', 'yandex', '15,60']
# ['email', 'promo', '13,20']
# ['sem', 'yandex', '9,80']
# ['sem', 'google', '14,80']
# ['sem', 'google', '14,40']
# ['sem', 'google', '14,00']
# ['brand', 'yandex', '20,00']
# ['sem', 'yandex', '16,20']
# ['email', 'promo', '11,00']
# ['cpa-partners', 'burgerclub', '10,80']
# ['seo', 'google', '22,60']
# ['seo', 'google', '22,40']
# ['sem', 'yandex', '24,40']
# ['seo', 'google', '16,60']
# ['sem', 'yandex', '8,60']
# ['seo', 'yandex', '12,40']
# ['cpa-partners', 'food-delivery', '16,20']
# ['email', 'promo', '24,00']
# ['sem', 'yandex', '18,80']
# ['email', 'promo', '11,80']
# ['sem', 'google', '9,40']
# ['sem', 'google', '11,20']
# ['email', 'promo', '19,00']
# ['sem', 'google', '23,40']
# ['cpc-partners', 'city-magazine', '17,00']
# ['seo', 'google', '20,80']
# ['email', 'promo', '15,60']
# ['cpc-partners', 'foody', '22,40']
# ['seo', 'yandex', '15,60']
# ['cpa-partners', 'food-delivery', '21,00']
# ...

# %% [markdown]
# Step 4. Splitting columns

# %%
with open('/Users/shopangali05/Downloads/My file/IT3-2208/4 семестр/python/laborotory work/laboratory work # 5 /data_3_columns.txt', 'r') as f:
    for line in f:
        line = line.strip().split('\t')
        medium = line[0]
        source = line[1]
        amount_paid = line[2].replace(',' ,'.')
#         print(type(line[2]))
        print(line)
        print(source, medium, amount_paid)
# Out:
# <class 'str'>
# ['seo', 'google', '20,20']
# google seo 20.20
# <class 'str'>
# ['sem', 'yandex', '15,60']
# yandex sem 15.60
# <class 'str'>
# ['email', 'promo', '13,20']
# promo email 13.20
# <class 'str'>
# ['sem', 'yandex', '9,80']
# yandex sem 9.80
# <class 'str'>
# ['sem', 'google', '14,80']
# google sem 14.80
# <class 'str'>
# ['sem', 'google', '14,40']
# google sem 14.40
# <class 'str'>
# ['sem', 'google', '14,00']
# google sem 14.00
# <class 'str'>
# ['brand', 'yandex', '20,00']
# yandex brand 20.00
# <class 'str'>
# ['sem', 'yandex', '16,20']
# yandex sem 16.20
# <class 'str'>
# ['email', 'promo', '11,00']
# promo email 11.00
# <class 'str'>
# ['cpa-partners', 'burgerclub', '10,80']
# burgerclub cpa-partners 10.80
# <class 'str'>
# ['seo', 'google', '22,60']
# google seo 22.60
# <class 'str'>
# ['seo', 'google', '22,40']
# google seo 22.40
# <class 'str'>
# ['sem', 'yandex', '24,40']
# yandex sem 24.40
# <class 'str'>
# ['seo', 'google', '16,60']
# google seo 16.60
# ...

# %% [markdown]
# strip(),split(),join(),replace()

# %% [markdown]
# Step 5. Get a number from the string line

# %%
with open('/Users/shopangali05/Downloads/My file/IT3-2208/4 семестр/python/laborotory work/laboratory work # 5 /data_3_columns.txt', 'r') as f:
    for line in f:
        line = line.strip().split('\t')
        medium = line[0]
        source = line[1]
        amount_paid = float(line[2].replace(',' ,'.'))
        print( source, medium, amount_paid )
        print("Amount paid:", amount_paid)
# Out:
# google seo 20.2
# Amount paid: 20.2
# yandex sem 15.6
# Amount paid: 15.6
# promo email 13.2
# Amount paid: 13.2
# yandex sem 9.8
# Amount paid: 9.8
# google sem 14.8
# Amount paid: 14.8
# google sem 14.4
# Amount paid: 14.4
# google sem 14.0
# Amount paid: 14.0
# yandex brand 20.0
# Amount paid: 20.0
# yandex sem 16.2
# Amount paid: 16.2
# promo email 11.0
# Amount paid: 11.0
# burgerclub cpa-partners 10.8
# Amount paid: 10.8
# google seo 22.6
# Amount paid: 22.6
# google seo 22.4
# Amount paid: 22.4
# yandex sem 24.4
# Amount paid: 24.4
# google seo 16.6
# Amount paid: 16.6
# yandex sem 8.6
# Amount paid: 8.6
# yandex seo 12.4
# Amount paid: 12.4
# food-delivery cpa-partners 16.2
# Amount paid: 16.2
# promo email 24.0
# Amount paid: 24.0
# yandex sem 18.8
# Amount paid: 18.8
# promo email 11.8
# Amount paid: 11.8
# google sem 9.4
# Amount paid: 9.4
# google sem 11.2
# Amount paid: 11.2
# promo email 19.0
# Amount paid: 19.0
# google sem 23.4
# Amount paid: 23.4
# ...

# %% [markdown]
# Step 6. Counting the amount in files

# %%
s = []
with open('/Users/shopangali05/Downloads/My file/IT3-2208/4 семестр/python/laborotory work/laboratory work # 5 /data_3_columns.txt', 'r') as f:
    for line in f:
        line = line.strip().split('\t')
        medium = line[0]
        source = line[1]
        amount_paid = float(line[2].replace(',' ,'.'))
        s.append(amount_paid)
#         print( source, medium, amount_paid )
#         print("Amount paid:", amount_paid)
total_sum = 0 
for i in s:
    total_sum +=i
    print("Current expenses:", total_sum)
print("The total sum {}".format(total_sum))
# Out:
# Current expenses: 20.2
# Current expenses: 35.8
# Current expenses: 49.0
# Current expenses: 58.8
# Current expenses: 73.6
# Current expenses: 88.0
# Current expenses: 102.0
# Current expenses: 122.0
# Current expenses: 138.2
# Current expenses: 149.2
# Current expenses: 160.0
# Current expenses: 182.6
# Current expenses: 205.0
# Current expenses: 229.4
# Current expenses: 246.0
# Current expenses: 254.6
# Current expenses: 267.0
# Current expenses: 283.2
# Current expenses: 307.2
# Current expenses: 326.0
# Current expenses: 337.8
# Current expenses: 347.2
# Current expenses: 358.4
# Current expenses: 377.4
# Current expenses: 400.79999999999995
# Current expenses: 417.79999999999995
# Current expenses: 438.59999999999997
# Current expenses: 454.2
# Current expenses: 476.59999999999997
# Current expenses: 492.2
# Current expenses: 513.2
# Current expenses: 535.6
# Current expenses: 556.0
# Current expenses: 582.0
# Current expenses: 600.4
# Current expenses: 615.0
# ...

# %% [markdown]
# Step 7. Counting amount with filter

# %%
total_sum = 0 
with open('/Users/shopangali05/Downloads/My file/IT3-2208/4 семестр/python/laborotory work/laboratory work # 5 /data_3_columns.txt', 'r') as f:
    for line in f:
        line = line.strip().split('\t')
        medium = line[0]
        source = line[1]
        amount_paid = float(line[2].replace(',' ,'.'))
        if source == "google":
            total_sum += amount_paid
            print('Current expenses google: {}'.format(total_sum))
print(f"Total sum the source is google {total_sum}")
# Out:
# Current expenses google: 20.2
# Current expenses google: 35.0
# Current expenses google: 49.4
# Current expenses google: 63.4
# Current expenses google: 86.0
# Current expenses google: 108.4
# Current expenses google: 125.0
# Current expenses google: 134.4
# Current expenses google: 145.6
# Current expenses google: 169.0
# Current expenses google: 189.8
# Current expenses google: 212.20000000000002
# Current expenses google: 232.60000000000002
# Current expenses google: 251.60000000000002
# Current expenses google: 268.0
# Current expenses google: 289.0
# Current expenses google: 306.4
# Current expenses google: 318.59999999999997
# Current expenses google: 336.4
# Current expenses google: 356.2
# Current expenses google: 373.8
# Current expenses google: 395.8
# Current expenses google: 411.8
# Current expenses google: 425.2
# Current expenses google: 447.59999999999997
# Current expenses google: 461.59999999999997
# Current expenses google: 478.2
# Current expenses google: 496.0
# ...

# %%
s = []
total_sum = 0 
with open('/Users/shopangali05/Downloads/My file/IT3-2208/4 семестр/python/laborotory work/laboratory work # 5 /data_3_columns.txt', 'r') as f:
    for line in f:
        line = line.strip().split('\t')
        medium = line[0]
        source = line[1]
        amount_paid = float(line[2].replace(',' ,'.'))
        s.append((medium, source, amount_paid))       
    
       
for i in range(len(s)):
    s[i] = list(s[i])
for i in s:
    if "google" in i[1]:
        total_sum+=i[2]
        print('Current expenses google: {:.2f}'.format(total_sum))
# Out:
# Current expenses google: 20.20
# Current expenses google: 35.00
# Current expenses google: 49.40
# Current expenses google: 63.40
# Current expenses google: 86.00
# Current expenses google: 108.40
# Current expenses google: 125.00
# Current expenses google: 134.40
# Current expenses google: 145.60
# Current expenses google: 169.00
# Current expenses google: 189.80
# Current expenses google: 212.20
# Current expenses google: 232.60
# Current expenses google: 251.60
# Current expenses google: 268.00
# Current expenses google: 289.00
# Current expenses google: 306.40
# Current expenses google: 318.60
# Current expenses google: 336.40
# Current expenses google: 356.20
# Current expenses google: 373.80
# Current expenses google: 395.80
# Current expenses google: 411.80
# Current expenses google: 425.20
# Current expenses google: 447.60
# Current expenses google: 461.60
# Current expenses google: 478.20
# Current expenses google: 496.00
# Current expenses google: 505.00
# ...
